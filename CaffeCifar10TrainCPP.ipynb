# %% [markdown]
# # Train your Cifar10 Neural Network

# %% [markdown]
# This first part is the training part.  You need to do it if you haven't trained your network for cifar10 like http://caffe.berkeleyvision.org/gathered/examples/cifar10.html

# %% [markdown]
# Get the cifar

# %%
# %%bash
#
# export CAFFE=/opt/caffe
#
# cd $CAFFE
# ./data/cifar10/get_cifar10.sh
# Out:
# Downloading...
# Unzipping...
# Done.
# --2015-09-15 18:56:08--  http://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170052171 (162M) [application/x-gzip]
# Saving to: â€˜cifar-10-binary.tar.gzâ€™
#
#      0K .......... .......... .......... .......... ..........  0%  245M 1s
#     50K .......... .......... .......... .......... ..........  0%  382M 1s
#    100K .......... .......... .......... .......... ..........  0% 1.85M 29s
#    150K .......... .......... .......... .......... ..........  0% 1.86M 44s
#    200K .......... .......... .......... .......... ..........  0% 41.1M 36s
#    250K .......... .......... .......... .......... ..........  0% 2.00M 43s
#    300K .......... .......... .......... .......... ..........  0% 31.3M 38s
# ...

# %% [markdown]
# Create cifar10

# %%
# %%bash
#
# export CAFFE=/opt/caffe
#
# cd $CAFFE
# ./examples/cifar10/create_cifar10.sh
#
# ls -al ./examples/cifar10/mean.binaryproto
# ls -al ./examples/cifar10/cifar10_train_lmdb
# ls -al ./examples/cifar10/cifar10_test_lmdb
# Out:
# Creating lmdb...
# Computing image mean...
# Done.
# -rw-rw-r-- 1 ubuntu ubuntu 12299 Sep 15 19:04 ./examples/cifar10/mean.binaryproto
# total 201216
# drwxr--r-- 2 ubuntu ubuntu      4096 Sep 15 19:03 .
# drwxrwxr-x 4 ubuntu ubuntu      4096 Sep 15 19:03 ..
# -rw-rw-r-- 1 ubuntu ubuntu 206032896 Sep 15 19:03 data.mdb
# -rw-rw-r-- 1 ubuntu ubuntu      8192 Sep 15 19:04 lock.mdb
# total 40264
# drwxr--r-- 2 ubuntu ubuntu     4096 Sep 15 19:03 .
# drwxrwxr-x 4 ubuntu ubuntu     4096 Sep 15 19:03 ..
# -rw-rw-r-- 1 ubuntu ubuntu 41218048 Sep 15 19:04 data.mdb
# -rw-rw-r-- 1 ubuntu ubuntu     8192 Sep 15 19:03 lock.mdb
# libdc1394 error: Failed to initialize libdc1394
# libdc1394 error: Failed to initialize libdc1394

# %%
# %%bash
#
# export CAFFE=/opt/caffe
#
# cd $CAFFE
# #./examples/cifar10/train_quick.sh
#
# TOOLS=./build/tools
#
# $TOOLS/caffe train \
#   --solver=examples/cifar10/cifar10_quick_solver.prototxt
#
# # reduce learning rate by factor of 10 after 8 epochs
# $TOOLS/caffe train \
#   --solver=examples/cifar10/cifar10_quick_solver_lr1.prototxt \
#   --snapshot=examples/cifar10/cifar10_quick_iter_4000.solverstate
# Out:
# libdc1394 error: Failed to initialize libdc1394
# I0915 19:09:08.280465  2005 caffe.cpp:183] Using GPUs 0
# I0915 19:09:08.437324  2005 solver.cpp:54] Initializing solver from parameters:
# test_iter: 100
# test_interval: 500
# base_lr: 0.001
# display: 100
# max_iter: 4000
# lr_policy: "fixed"
# momentum: 0.9
# weight_decay: 0.004
# snapshot: 4000
# snapshot_prefix: "examples/cifar10/cifar10_quick"
# solver_mode: GPU
# device_id: 0
# net: "examples/cifar10/cifar10_quick_train_test.prototxt"
# I0915 19:09:08.437386  2005 solver.cpp:96] Creating training net from net file: examples/cifar10/cifar10_quick_train_test.prototxt
# I0915 19:09:08.437918  2005 net.cpp:339] The NetState phase (0) differed from the phase (1) specified by a rule in layer cifar
# I0915 19:09:08.437949  2005 net.cpp:339] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0915 19:09:08.438086  2005 net.cpp:50] Initializing net from parameters:
# name: "CIFAR10_quick"
# ...

# %% [markdown]
# Accuracy on Test went from 72% to 75%

# %%
# %%bash
#
# export CAFFE=/opt/caffe
#
# cd $CAFFE
# #./examples/cifar10/train_full.sh
# TOOLS=./build/tools
#
# $TOOLS/caffe train \
#     --solver=examples/cifar10/cifar10_full_solver.prototxt
# Out:
# libdc1394 error: Failed to initialize libdc1394
# I0915 19:14:35.447490  2064 caffe.cpp:183] Using GPUs 0
# I0915 19:14:35.841115  2064 solver.cpp:54] Initializing solver from parameters:
# test_iter: 100
# test_interval: 1000
# base_lr: 0.001
# display: 200
# max_iter: 60000
# lr_policy: "fixed"
# momentum: 0.9
# weight_decay: 0.004
# snapshot: 10000
# snapshot_prefix: "examples/cifar10/cifar10_full"
# solver_mode: GPU
# device_id: 0
# net: "examples/cifar10/cifar10_full_train_test.prototxt"
# I0915 19:14:35.841187  2064 solver.cpp:96] Creating training net from net file: examples/cifar10/cifar10_full_train_test.prototxt
# I0915 19:14:35.842481  2064 net.cpp:339] The NetState phase (0) differed from the phase (1) specified by a rule in layer cifar
# I0915 19:14:35.842517  2064 net.cpp:339] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0915 19:14:35.842669  2064 net.cpp:50] Initializing net from parameters:
# name: "CIFAR10_full"
# ...

# %% [markdown]
# Accuracy on Test went from 75% to 78%

# %%
# %%bash
#
# export CAFFE=/opt/caffe
#
# cd $CAFFE
# #./examples/cifar10/train_full.sh
# TOOLS=./build/tools
#
# # reduce learning rate by factor of 10
# $TOOLS/caffe train \
#     --solver=examples/cifar10/cifar10_full_solver_lr1.prototxt \
#     --snapshot=examples/cifar10/cifar10_full_iter_60000.solverstate
# Out:
# libdc1394 error: Failed to initialize libdc1394
# I0915 19:42:30.957741  2109 caffe.cpp:183] Using GPUs 0
# I0915 19:42:31.352195  2109 solver.cpp:54] Initializing solver from parameters:
# test_iter: 100
# test_interval: 1000
# base_lr: 0.0001
# display: 200
# max_iter: 65000
# lr_policy: "fixed"
# momentum: 0.9
# weight_decay: 0.004
# snapshot: 5000
# snapshot_prefix: "examples/cifar10/cifar10_full"
# solver_mode: GPU
# device_id: 0
# net: "examples/cifar10/cifar10_full_train_test.prototxt"
# I0915 19:42:31.352259  2109 solver.cpp:96] Creating training net from net file: examples/cifar10/cifar10_full_train_test.prototxt
# I0915 19:42:31.352795  2109 net.cpp:339] The NetState phase (0) differed from the phase (1) specified by a rule in layer cifar
# I0915 19:42:31.352829  2109 net.cpp:339] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0915 19:42:31.352972  2109 net.cpp:50] Initializing net from parameters:
# name: "CIFAR10_full"
# ...

# %% [markdown]
# Accuracy on Test went from 78% to 81.49%

# %%
# %%bash
#
# export CAFFE=/opt/caffe
#
# cd $CAFFE
# #./examples/cifar10/train_full.sh
# TOOLS=./build/tools
#
# # reduce learning rate by factor of 10
# $TOOLS/caffe train \
#     --solver=examples/cifar10/cifar10_full_solver_lr2.prototxt \
#     --snapshot=examples/cifar10/cifar10_full_iter_65000.solverstate
# Out:
# libdc1394 error: Failed to initialize libdc1394
# I0915 19:46:57.451453  2129 caffe.cpp:183] Using GPUs 0
# I0915 19:46:57.851028  2129 solver.cpp:54] Initializing solver from parameters:
# test_iter: 100
# test_interval: 1000
# base_lr: 1e-05
# display: 200
# max_iter: 70000
# lr_policy: "fixed"
# momentum: 0.9
# weight_decay: 0.004
# snapshot: 5000
# snapshot_prefix: "examples/cifar10/cifar10_full"
# solver_mode: GPU
# device_id: 0
# net: "examples/cifar10/cifar10_full_train_test.prototxt"
# I0915 19:46:57.851093  2129 solver.cpp:96] Creating training net from net file: examples/cifar10/cifar10_full_train_test.prototxt
# I0915 19:46:57.851601  2129 net.cpp:339] The NetState phase (0) differed from the phase (1) specified by a rule in layer cifar
# I0915 19:46:57.851632  2129 net.cpp:339] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0915 19:46:57.851766  2129 net.cpp:50] Initializing net from parameters:
# name: "CIFAR10_full"
# ...

# %% [markdown]
# Accuracy on Test went from 81.49% to 81.78%
